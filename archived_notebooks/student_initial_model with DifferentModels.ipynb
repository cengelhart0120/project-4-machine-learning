# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf


#from google.colab import files

# %%
#uploaded = files.upload()

# %%
#uploaded_2 = files.upload()

# %%
math_data = pd.read_csv("math_success.csv")
portuguese_data = pd.read_csv("portuguese_success.csv")

math_df = pd.DataFrame(math_data)
portuguese_df = pd.DataFrame(portuguese_data)

# %%
math_df.head()
# Out:
#   school sex  age address famsize pstatus  medu  fedu     mjob      fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  dalc  walc health absences  g1  g2  g3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
math_df["g3"] = math_df["g3"].astype(int)
math_df["pass_fail"] = (math_df["g3"] >= 10).astype(int)

# %%
math_df = math_df.drop(columns = "g3")

# %%
math_df = pd.get_dummies(math_df)

# %%
import matplotlib.pyplot as plt
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import SGDClassifier

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = math_df.corr()
plt.figure(figsize=(16, 16))
sns.heatmap(corr, annot=True, cmap="Reds")
plt.title('Correlation Heatmap', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(math_df.corr()[['pass_fail']].sort_values(by='pass_fail', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Student Success', fontdict={'fontsize':18}, pad=16);

# %%
X = math_df.drop(columns = "pass_fail", axis = 1)
y= math_df["pass_fail"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
features = X_train_scaled.shape[1]

nodes_layer1 = 100

nodes_layer2 = 80

nn = tf.keras.models.Sequential()

# First hidden layer

nn.add(tf.keras.layers.Dense(units = nodes_layer1, input_dim = features, activation = "relu"))

# Second hidden layer

nn.add(tf.keras.layers.Dense(units = nodes_layer2, activation = "relu"))

# Output layer

nn.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# C:\Users\katea\anaconda3\envs\dev\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 100)                 │           5,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 80)                  │           8,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              81 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,061 (54.93 KB)
#  Trainable params: 14,061 (54.93 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
nn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
fitted_model = nn.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5044 - loss: 0.7196
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7027 - loss: 0.5658
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4430
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.3762
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8860 - loss: 0.3190
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9399 - loss: 0.2466
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9206 - loss: 0.2381
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9712 - loss: 0.1766
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9683 - loss: 0.1524
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.1292
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.0962
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9743 - loss: 0.0839
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0699
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0689
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0519
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0468
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0354
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0285
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0309
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0250
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0224
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.7299e-04
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.7874e-04
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 8.8928e-04
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.8097e-04
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.4655e-04
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.3726e-04
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.6178e-04
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.1492e-04
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.0531e-04
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.4119e-04
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.5555e-04
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.1502e-04
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.0740e-04
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.8567e-04
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.4926e-04
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.3295e-04
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.5575e-04
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.1865e-04
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.4138e-04
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.6010e-04
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.6350e-04
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.4832e-04
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.7813e-04
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.4273e-04
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.6507e-04
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.6773e-04
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.5078e-04
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.1100e-04
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.7346e-04
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.0842e-04
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.5079e-04
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.6866e-04
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.5858e-04
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.2376e-04
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.3291e-04
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.4835e-04
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.8215e-04
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.9303e-04
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.2861e-04
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.3055e-04
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8827e-04
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8795e-04

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - 55ms/step - accuracy: 0.8586 - loss: 0.4351
# Loss: 0.43510663509368896, Accuracy: 0.8585858345031738

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import SGDClassifier

# %%
# Decision Tree Model model
tree = DecisionTreeClassifier(min_samples_leaf=8)
t= tree.fit(X_train, y_train)
print("Decision Tree Model Score" , ":" , t.score(X_train, y_train) , "," , 
      "Cross Validation Score" ,":" , t.score(X_test, y_test))
# Out:
# Decision Tree Model Score : 0.9459459459459459 , Cross Validation Score : 0.898989898989899

# %%
len(list(X_train))
# Out:
# 58

# %%
# find a good # of estimators

ne=[]
for i in range(1,59):
    forest = RandomForestClassifier()
    f = forest.fit(X_train, y_train)
    fs = f.score(X_test, y_test)
    ne.append(fs)
ne = pd.Series(ne)
ne.where(ne==ne.max()).dropna()
# Out:
# 0    0.939394
# 8    0.939394
# dtype: float64

# %%
# find a good # of min_samples_leaf


ne=[]
for i in range(1,62):
    forest = RandomForestClassifier(n_estimators=26, min_samples_leaf=i)
    f = forest.fit(X_train, y_train)
    fs = f.score(X_test, y_test)
    ne.append(fs)
ne = pd.Series(ne)
ne.where(ne==ne.max()).dropna()
# Out:
# 0    0.929293
# 6    0.929293
# dtype: float64

# %%
# Random Forest Model
#n_estimators: This parameter specifies the number of decision trees in the forest. 
#min_samples_leaf: This parameter specifies the minimum number of samples required to be at a leaf node. It controls the depth of the trees and prevents overfitting by setting a threshold for how many samples should be present at the end nodes.
#Overall, a test accuracy of 0.97 and a cross-validation score of 0.9 indicate that your Random Forest model performs well and generalizes effectively


forest = RandomForestClassifier(n_estimators=18, min_samples_leaf=2)
f = forest.fit(X_train, y_train)
print("Random Forest Model Score" , ":" , f.score(X_train, y_train) , "," ,
      "Cross Validation Score" ,":" , f.score(X_test, y_test))
# Out:
# Random Forest Model Score : 0.9831081081081081 , Cross Validation Score : 0.9090909090909091

# %%
#SVC Model -Support Vector Classifier (SVC) model using scikit-learn's SVC class. 
svc = SVC()
s= svc.fit(X_train, y_train)
print("SVC Model Score" , ":" , s.score(X_train, y_train) , "," ,
      "Cross Validation Score" ,":" , s.score(X_test, y_test))
# Out:
# SVC Model Score : 0.902027027027027 , Cross Validation Score : 0.9090909090909091

# %%
lr = LogisticRegression(multi_class='multinomial', solver='newton-cg',fit_intercept=True)

# %%
# find optimal number of features to use in the model


ks=[]
for i in range(1,59):
    sk = SelectKBest(chi2, k=i)
    x_new = sk.fit_transform(X_train,y_train)
    x_new_test=sk.fit_transform(X_test,y_test)
    l = lr.fit(x_new, y_train)
    ll = l.score(x_new_test, y_test)
    ks.append(ll)  
    
ks = pd.Series(ks)
ks = ks.reindex(list(range(1,59)))
ks
# Out:
# 1     0.909091
# 2     0.909091
# 3     0.909091
# 4     0.696970
# 5     0.787879
# 6     0.838384
# 7     0.818182
# 8     0.838384
# 9     0.818182
# 10    0.909091
# 11    0.828283
# 12    0.818182
# 13    0.383838
# 14    0.777778
# 15    0.757576
# 16    0.343434
# 17    0.333333
# 18    0.848485
# 19    0.848485
# 20    0.848485
# 21    0.888889
# 22    0.898990
# 23    0.888889
# 24    0.888889
# 25    0.313131
# 26    0.313131
# 27    0.313131
# 28    0.313131
# 29    0.313131
# 30    0.313131
# 31    0.313131
# 32    0.313131
# 33    0.828283
# 34    0.878788
# 35    0.777778
# 36    0.767677
# 37    0.313131
# 38    0.313131
# 39    0.313131
# 40    0.313131
# 41    0.313131
# 42    0.313131
# 43    0.313131
# 44    0.313131
# 45    0.383838
# 46    0.343434
# 47    0.292929
# 48    0.303030
# 49    0.353535
# 50    0.414141
# 51    0.424242
# 52    0.939394
# 53    0.929293
# 54    0.898990
# 55    0.929293
# 56    0.888889
# 57    0.919192
# 58         NaN
# dtype: float64

# %%
plt.figure(figsize=(10,5))
ks.plot.line()
plt.title('Feature Selection', fontsize=20)
plt.xlabel('Number of Feature Used', fontsize=16)
plt.ylabel('Prediction Accuracy', fontsize=16)
# Out:
# Text(0, 0.5, 'Prediction Accuracy')

# %%
ks.where(ks==ks.max()).dropna()
# Out:
# 52    0.939394
# dtype: float64

# %%
# Logistic Regression
#SelectKBest: SelectKBest is a feature selection method in scikit-learn that selects the top k features based on a given scoring function
#k=2: This parameter specifies the number of features to select.
#using scikit-learn's SelectKBest method with the Chi-squared (chi2) scoring function, then fitting a logistic regression model with the selected features
#This code snippet first selects the best 6 features using the Chi-squared scoring function.
#it transforms both the training and test data using these selected features,initializes a logistic regression model and fits it on the transformed training data. Finally, it evaluates the model's performance on both the training and test sets.
#You can adjust the number of features (k parameter) or try different feature selection methods and models based on your specific problem and data characteristics

sk = SelectKBest(chi2, k=8)
x_new = sk.fit_transform(X_train,y_train)
x_new_test=sk.fit_transform(X_test,y_test)
lr = lr.fit(x_new, y_train)
print("Logistic Regression Model Score" , ":" , lr.score(x_new, y_train) , "," ,
      "Cross Validation Score" ,":" , lr.score(x_new_test, y_test))
# Out:
# Logistic Regression Model Score : 0.9222972972972973 , Cross Validation Score : 0.8181818181818182

# %%
#Ada Boost Model
#AdaBoost is an ensemble learning method that combines multiple weak classifiers to create a strong classifier. 
#This code creates an AdaBoost classifier with 5 base estimators (decision trees by default). It then fits the model to the training data and evaluates its performance on both the training and test sets.
ada = AdaBoostClassifier(n_estimators=8)
af = ada.fit(X_train, y_train)
print("Ada Boost Model Score" , ":" , af.score(X_train, y_train) , "," ,
      "Cross Validation Score" ,":" , af.score(X_test, y_test))
# Out:
# Ada Boost Model Score : 0.9391891891891891 , Cross Validation Score : 0.8888888888888888

# %%
#Stochastic Gradient Descent Model
#SGD is an optimization algorithm used to minimize a loss function, commonly used in training linear classifiers.
#This code creates an SGD classifier and fits it to the training data. It then evaluates the model's performance on both the training and test sets.
sgd = SGDClassifier()
sf = sgd.fit(X_train, y_train)
print("Stochastic Gradient Descent Model Score" , ":" , sf.score(X_train, y_train) , "," ,
      "Cross Validation Score" ,":" , sf.score(X_test, y_test))
# Out:
# Stochastic Gradient Descent Model Score : 0.9155405405405406 , Cross Validation Score : 0.8787878787878788

# %%
portuguese_df.head()
# Out:
#   school sex  age address famsize pstatus  medu  fedu     mjob      fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  dalc  walc health absences  g1  g2  g3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
portuguese_df["g3"] = portuguese_df["g3"].astype(int)
portuguese_df["pass_fail"] = (portuguese_df["g3"] >= 10).astype(int)

# %%
portuguese_df = portuguese_df.drop(columns = "g3")

# %%
portuguese_df = pd.get_dummies(portuguese_df)

# %%
p_X = portuguese_df.drop(columns = "pass_fail", axis = 1)
p_y= portuguese_df["pass_fail"]

p_X_train, p_X_test, p_y_train, p_y_test = train_test_split(p_X, p_y, random_state = 1)

# %%
p_scaler = StandardScaler()

p_X_scaler = scaler.fit(p_X_train)

p_X_train_scaled = p_X_scaler.transform(p_X_train)
p_X_test_scaled = p_X_scaler.transform(p_X_test)

# %%
#Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

p_features = p_X_train_scaled.shape[1]

p_nodes_layer1 = 100

p_nodes_layer2 = 80

p_nn = tf.keras.models.Sequential()

# First hidden layer

p_nn.add(tf.keras.layers.Dense(units = nodes_layer1, input_dim = features, activation = "relu"))

# Second hidden layer

p_nn.add(tf.keras.layers.Dense(units = nodes_layer2, activation = "relu"))

# Output layer

p_nn.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))

# Check the structure of the model
p_nn.summary()
# Out:
# C:\Users\katea\anaconda3\envs\dev\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 100)                 │           5,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 80)                  │           8,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              81 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,061 (54.93 KB)
#  Trainable params: 14,061 (54.93 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
p_nn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
p_nn_fitted_model = p_nn.fit(p_X_train_scaled, p_y_train, epochs = 100)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8384 - loss: 0.5013
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8548 - loss: 0.3193
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9157 - loss: 0.2329
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9324 - loss: 0.1956
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9354 - loss: 0.1558
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.1388
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9682 - loss: 0.1067
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9814 - loss: 0.0976
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9934 - loss: 0.0698
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0640
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9944 - loss: 0.0423
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0440
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0384
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.0218
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0201
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0194
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.7244e-04
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.3141e-04
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.9630e-04
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.2468e-04
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.5306e-04
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.2641e-04
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.4433e-04
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.9442e-04
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.7254e-04
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.9359e-04
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.1713e-04
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.8348e-04
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.3526e-04
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.9929e-04
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.1205e-04
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.1155e-04
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.6840e-04
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.6230e-04
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.5690e-04
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.9094e-04
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.5506e-04
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.9032e-04
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.0470e-04
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.4484e-04
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.0199e-04
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.5136e-04
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.8254e-04
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.5416e-04
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.9141e-04
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.7334e-04
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.5215e-04
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.5737e-04
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.3367e-04
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.7339e-04
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.4951e-04
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.3617e-04
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.0170e-04
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.3036e-04
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.2800e-04
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.0749e-04
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9010e-04
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.0076e-04
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.7077e-04
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.8936e-04
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.7889e-04
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.6692e-04
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5460e-04
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.7056e-04
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4253e-04
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.6272e-04
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5931e-04
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5330e-04
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4874e-04
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3515e-04
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.2215e-04
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3400e-04
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.2512e-04
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.2252e-04

# %%
model_loss, model_accuracy = p_nn.evaluate(p_X_test_scaled,p_y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 6/6 - 0s - 29ms/step - accuracy: 0.9018 - loss: 0.6086
# Loss: 0.6085606217384338, Accuracy: 0.9018405079841614

# %%
# Decision Tree Model model
tree = DecisionTreeClassifier(min_samples_leaf=8)
t= tree.fit(p_X_train, p_y_train)
print("Decision Tree Model Score" , ":" , t.score(p_X_train, p_y_train) , "," , 
      "Cross Validation Score" ,":" , t.score(p_X_test, p_y_test))
# Out:
# Decision Tree Model Score : 0.9526748971193416 , Cross Validation Score : 0.9141104294478528

# %%
# find a good # of estimators

ne=[]
for i in range(1,59):
    forest = RandomForestClassifier()
    f = forest.fit(p_X_train, p_y_train)
    fs = f.score(p_X_test, p_y_test)
    ne.append(fs)
ne = pd.Series(ne)
ne.where(ne==ne.max()).dropna()
# Out:
# 2     0.92638
# 7     0.92638
# 10    0.92638
# 12    0.92638
# 16    0.92638
# 18    0.92638
# 25    0.92638
# 26    0.92638
# 36    0.92638
# 41    0.92638
# 43    0.92638
# 45    0.92638
# 50    0.92638
# dtype: float64

# %%
# find a good # of min_samples_leaf


ne=[]
for i in range(1,59):
    forest = RandomForestClassifier(n_estimators=26, min_samples_leaf=i)
    f = forest.fit(p_X_train, p_y_train)
    fs = f.score(p_X_test, p_y_test)
    ne.append(fs)
ne = pd.Series(ne)
ne.where(ne==ne.max()).dropna()
# Out:
# 3     0.92638
# 22    0.92638
# dtype: float64

# %%
# Random Forest Model
#n_estimators: This parameter specifies the number of decision trees in the forest. 
#min_samples_leaf: This parameter specifies the minimum number of samples required to be at a leaf node. It controls the depth of the trees and prevents overfitting by setting a threshold for how many samples should be present at the end nodes.
#Overall, a test accuracy of 0.96 and a cross-validation score of 0.75 indicate that your Random Forest model performs well and generalizes effectively


forest = RandomForestClassifier(n_estimators=26, min_samples_leaf=2)
f = forest.fit(p_X_train, p_y_train)
print("Random Forest Model Score" , ":" , f.score(p_X_train, p_y_train) , "," ,
      "Cross Validation Score" ,":" , f.score(p_X_test, p_y_test))
# Out:
# Random Forest Model Score : 0.9897119341563786 , Cross Validation Score : 0.9263803680981595

# %%
#SVC Model
svc = SVC()
s= svc.fit(p_X_train, p_y_train)
print("SVC Model Score" , ":" , s.score(p_X_train, p_y_train) , "," ,
      "Cross Validation Score" ,":" , s.score(p_X_test, p_y_test))
# Out:
# SVC Model Score : 0.9362139917695473 , Cross Validation Score : 0.901840490797546

# %%
lr = LogisticRegression(multi_class='multinomial', solver='newton-cg',fit_intercept=True)

# %%
# find optimal number of features to use in the model


ks=[]
for i in range(1,59):
    sk = SelectKBest(chi2, k=i)
    p_x_new = sk.fit_transform(p_X_train, p_y_train)
    p_x_new_test=sk.fit_transform(p_X_test, p_y_test)
    l = lr.fit(p_x_new, p_y_train)
    ll = l.score(p_x_new_test, p_y_test)
    ks.append(ll)  
    
ks = pd.Series(ks)
ks = ks.reindex(list(range(1,59)))
ks
# Out:
# 1     0.920245
# 2     0.901840
# 3     0.907975
# 4     0.306748
# 5     0.920245
# 6     0.920245
# 7     0.907975
# 8     0.865031
# 9     0.865031
# 10    0.858896
# 11    0.858896
# 12    0.184049
# 13    0.184049
# 14    0.865031
# 15    0.852761
# 16    0.901840
# 17    0.165644
# 18    0.165644
# 19    0.165644
# 20    0.165644
# 21    0.165644
# 22    0.907975
# 23    0.858896
# 24    0.865031
# 25    0.883436
# 26    0.871166
# 27    0.858896
# 28    0.852761
# 29    0.852761
# 30    0.865031
# 31    0.877301
# 32    0.901840
# 33    0.165644
# 34    0.889571
# 35    0.889571
# 36    0.165644
# 37    0.165644
# 38    0.165644
# 39    0.165644
# 40    0.165644
# 41    0.165644
# 42    0.165644
# 43    0.165644
# 44    0.656442
# 45    0.889571
# 46    0.895706
# 47    0.877301
# 48    0.914110
# 49    0.907975
# 50    0.926380
# 51    0.926380
# 52    0.926380
# 53    0.165644
# 54    0.165644
# 55    0.165644
# 56    0.165644
# 57    0.914110
# 58         NaN
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
ks.plot.line()
plt.title('Feature Selection', fontsize=20)
plt.xlabel('Number of Feature Used', fontsize=16)
plt.ylabel('Prediction Accuracy', fontsize=16)
# Out:
# Text(0, 0.5, 'Prediction Accuracy')

# %%
ks.where(ks==ks.max()).dropna()
# Out:
# 50    0.92638
# 51    0.92638
# 52    0.92638
# dtype: float64

# %%
# Logistic Regression
#SelectKBest: SelectKBest is a feature selection method in scikit-learn that selects the top k features based on a given scoring function
#k=2: This parameter specifies the number of features to select.
#using scikit-learn's SelectKBest method with the Chi-squared (chi2) scoring function, then fitting a logistic regression model with the selected features
#This code snippet first selects the best 6 features using the Chi-squared scoring function.
#it transforms both the training and test data using these selected features,initializes a logistic regression model and fits it on the transformed training data. Finally, it evaluates the model's performance on both the training and test sets.
#You can adjust the number of features (k parameter) or try different feature selection methods and models based on your specific problem and data characteristics

sk = SelectKBest(chi2, k=6)
p_x_new = sk.fit_transform(p_X_train,p_y_train)
p_x_new_test=sk.fit_transform(p_X_test,p_y_test)
lr = lr.fit(p_x_new, p_y_train)
print("Logistic Regression Model Score" , ":" , lr.score(p_x_new, p_y_train) , "," ,
      "Cross Validation Score" ,":" , lr.score(p_x_new_test, p_y_test))
# Out:
# Logistic Regression Model Score : 0.9403292181069959 , Cross Validation Score : 0.9202453987730062

# %%
#Ada Boost Model
#AdaBoost is an ensemble learning method that combines multiple weak classifiers to create a strong classifier. 
#This code creates an AdaBoost classifier with 5 base estimators (decision trees by default). It then fits the model to the training data and evaluates its performance on both the training and test sets.
ada = AdaBoostClassifier(n_estimators=6)
af = ada.fit(p_X_train, p_y_train)
print("Ada Boost Model Score" , ":" , af.score(p_X_train, p_y_train) , "," ,
      "Cross Validation Score" ,":" , af.score(p_X_test, p_y_test))
# Out:
# Ada Boost Model Score : 0.9465020576131687 , Cross Validation Score : 0.9079754601226994

# %%
#Stochastic Gradient Descent Model
#SGD is an optimization algorithm used to minimize a loss function, commonly used in training linear classifiers.
#This code snippet creates an SGD classifier and fits it to the training data. It then evaluates the model's performance on both the training and test sets.
sgd = SGDClassifier()
sf = sgd.fit(p_X_train, p_y_train)
print("Stochastic Gradient Descent Model Score" , ":" , sf.score(p_X_train, p_y_train) , "," ,
      "Cross Validation Score" ,":" , sf.score(p_X_test, p_y_test))
# Out:
# Stochastic Gradient Descent Model Score : 0.9279835390946503 , Cross Validation Score : 0.8895705521472392
