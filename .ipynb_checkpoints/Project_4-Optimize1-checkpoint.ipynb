# %% [markdown]
# - I added an extra layer and adjusted the nodes, that raised acc to 90.7.
# - I changed the get_dummies to the label encoder and that lowered the acc score.
# - I changed the activation function and that lowered the acc score slightly.
# - We adjusted the number of nodes per layer, raised score to 90.8
# - Tried the MinMaxScaler and lowered the acc to 88
# - Tried to use different percentages for Dropout but the model is still overfit(trained at 100% accuracy)
# - Switched optimizer to sgd with defaults and achieved 90.8
# - Model is not as overfit with "adam"
# - Tried adding stratify in TTS, brought the acc score to 88.7

# %%
#pip install ucimlrepo

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
import tensorflow as tf
from ucimlrepo import fetch_ucirepo

# Fetch dataset
student_performance = fetch_ucirepo(id=320)

# Extract features and targets
X = student_performance.data.features
y = student_performance.data.targets

# Convert features and targets to pandas DataFrames
X_df = pd.DataFrame(X, columns=student_performance.metadata.features)
y_df = pd.DataFrame(y, columns=student_performance.metadata.targets)

# Concatenate features and targets into a single DataFrame
student_df = pd.concat([X_df, y_df], axis=1)

# Display metadata
print(student_performance.metadata)

# Display variable information
print(student_performance.variables)
# Out:
# 2024-06-05 16:38:06.999821: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
student_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
student_df["G3"] = student_df["G3"].astype(int)
student_df["pass_fail"] = (student_df["G3"] >= 10).astype(int)

# %%
student_df = student_df.drop(columns = "G3")

# %% [markdown]
# # Encoding

# %%
student_df = pd.get_dummies(student_df)

# %%
# from sklearn import preprocessing 

# label_encoder = preprocessing.LabelEncoder()

# student_df['school']= label_encoder.fit_transform(student_df['school']) 
# student_df['sex']= label_encoder.fit_transform(student_df['sex']) 
# student_df['address']= label_encoder.fit_transform(student_df['address']) 
# student_df['famsize']= label_encoder.fit_transform(student_df['famsize']) 
# student_df['Pstatus']= label_encoder.fit_transform(student_df['Pstatus']) 
# student_df['Mjob']= label_encoder.fit_transform(student_df['Mjob']) 
# student_df['Fjob']= label_encoder.fit_transform(student_df['Fjob']) 
# student_df['reason']= label_encoder.fit_transform(student_df['reason']) 
# student_df['guardian']= label_encoder.fit_transform(student_df['guardian']) 
# student_df['schoolsup']= label_encoder.fit_transform(student_df['schoolsup'])
# student_df['famsup']= label_encoder.fit_transform(student_df['famsup']) 
# student_df['paid']= label_encoder.fit_transform(student_df['paid']) 
# student_df['activities']= label_encoder.fit_transform(student_df['activities']) 
# student_df['nursery']= label_encoder.fit_transform(student_df['nursery']) 
# student_df['higher']= label_encoder.fit_transform(student_df['higher']) 
# student_df['internet']= label_encoder.fit_transform(student_df['internet']) 
# student_df['romantic']= label_encoder.fit_transform(student_df['romantic'])

# %%
X = student_df.drop(columns = "pass_fail", axis = 1)
y= student_df["pass_fail"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %% [markdown]
# # Scaling

# %%
# scaler = MinMaxScaler()

# X_scaler = scaler.fit(X_train)

# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
features = X_train_scaled.shape[1]

nodes_layer1 = 100

nodes_layer2 = 50

nodes_layer3 = 30
nn = tf.keras.models.Sequential()

# First hidden layer

nn.add(tf.keras.layers.Dense(units = nodes_layer1, input_dim = features, activation = "relu"))
nn.add(tf.keras.layers.Dropout(0.4))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = nodes_layer2, activation = "relu"))
nn.add(tf.keras.layers.Dropout(0.4))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units = nodes_layer3, activation = "relu"))

# Output layer

nn.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               5900
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 30)                1530
#
#  dense_3 (Dense)             (None, 1)                 31
#
# ...
# Total params: 12,511
# Trainable params: 12,511
# Non-trainable params: 0
# _________________________________________________________________
# 2024-06-05 16:38:15.415164: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# ...

# %%
# from tensorflow.keras.optimizers import SGD
# sgd = SGD(learning_rate=0.01,momentum=0.9)
nn.compile(loss = "binary_crossentropy", optimizer = "sgd", metrics = ["accuracy"])

# %%
fitted_model = nn.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7901
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5124 - accuracy: 0.8128
# Epoch 3/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4958 - accuracy: 0.8251
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4546 - accuracy: 0.8436
# Epoch 5/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4514 - accuracy: 0.8374
# Epoch 6/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4414 - accuracy: 0.8436
# Epoch 7/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4294 - accuracy: 0.8457
# Epoch 8/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4410 - accuracy: 0.8395
# Epoch 9/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4428 - accuracy: 0.8457
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_train_scaled,y_train,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 16/16 - 0s - loss: 0.1375 - accuracy: 0.9609 - 235ms/epoch - 15ms/step
# Loss: 0.1375473588705063, Accuracy: 0.9609053730964661

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 6/6 - 0s - loss: 0.2285 - accuracy: 0.8896 - 43ms/epoch - 7ms/step
# Loss: 0.22846382856369019, Accuracy: 0.8895705342292786
